# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">👨‍💻 1. EDA for Telecom Company 😃😃</p>

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; margin: 20px 0;">
#
# ![customer_churn.jpeg](attachment:customer_churn.jpeg)
# </div>

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:center; width: 70%; margin: auto;">
# <h3 style="color:#D00000; margin-bottom: 20px;">📚 About the Author</h3>
#
# **Written by:** Faisal Mehmood
# **Submission Date:** 15-05-2025
# **Email:** [shahfaisal1234@gmail.com](mailto:shahfaisal1234@gmail.com)
#
# <h3 style="color:#D00000; margin-bottom: 20px;">🤝 Connect With Me</h3>
#
# [<img src="https://raw.githubusercontent.com/FortAwesome/Font-Awesome/6.x/svgs/brands/linkedin.svg" width="40" height="40" alt="LinkedIn" style="background-color: #ffffff; border-radius: 8px; padding: 5px;">](https://www.linkedin.com/in/fmehmood1122/)
# [<img src="https://raw.githubusercontent.com/FortAwesome/Font-Awesome/6.x/svgs/brands/github.svg" width="40" height="40" alt="GitHub" style="background-color: #ffffff; border-radius: 8px; padding: 5px;">](https://github.com/faisalmehmood2013)
# [<img src="https://raw.githubusercontent.com/FortAwesome/Font-Awesome/6.x/svgs/brands/facebook.svg" width="40" height="40" alt="Facebook" style="background-color: #ffffff; border-radius: 8px; padding: 5px;">](https://www.facebook.com/FMGillani01)
# [<img src="https://raw.githubusercontent.com/FortAwesome/Font-Awesome/6.x/svgs/brands/instagram.svg" width="40" height="40" alt="Instagram" style="background-color: #ffffff; border-radius: 8px; padding: 5px;">](https://www.instagram.com/fmgillani/)

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 70%; margin: auto;">
# <h3 style="color:#D00000; margin-bottom: 20px;">📊 About the Customer Churn Prediction Dataset:</h3>
#
# The <strong>Customer Churn Prediction Dataset</strong> is a synthetically generated collection that simulates real-world telecom customer data. It includes thousands of customer records, each described by <strong>nine key features</strong> used to predict whether a customer will churn (leave) or stay. The dataset is ideal for building predictive models and understanding customer retention patterns in the telecom industry.
#
# 1. 🔹 <strong>Key Features:</strong>
#     1. <strong>CustomerID</strong>: Unique identifier for each customer.
#     2. <strong>Gender</strong>: Customer's gender – Male or Female.
#     3. <strong>SeniorCitizen</strong>: Indicates whether the customer is a senior citizen (1) or not (0).
#     4. <strong>Tenure</strong>: Number of months the customer has been with the service.
#     5. <strong>MonthlyCharges</strong>: Monthly billing amount for the customer.
#     6. <strong>TotalCharges</strong>: Total amount billed (calculated as Tenure × MonthlyCharges).
#     7. <strong>Contract</strong>: Type of contract – Month-to-month, One year, or Two year.
#     8. <strong>PaymentMethod</strong>: Customer’s payment method – Electronic check, Mailed check, Bank transfer, or Credit card.
#     9. <strong>Churn</strong>: Indicates if the customer has churned (1) or not (0). This is the <strong>target variable</strong>.
#
# 2. 📁 <strong>Dataset Summary:</strong>
#     - <strong>Source</strong>: Synthetic dataset generated using NumPy and Pandas in Python.
#     - <strong>Total Records</strong>: Based on the value of <code>n</code> (custom sample size).
#     - <strong>Use Case</strong>: Churn prediction, subscription analysis, telecom customer insights.
#
# 3. 📌 <strong>Usefulness:</strong><br>
#
#     - Customer churn prediction projects
#     - Machine learning model training and evaluation
#     - Customer behavior and segmentation analysis
#
# </div>

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 70%; margin: auto;">
# <h3 style="color:#D00000; margin-bottom: 20px;">🔧 Problem Statement:</h3>
#
# Due to increasing competition and market saturation, customer retention is a critical challenge for telecom companies. Losing customers (churn) directly impacts revenues and profitability. Identifying and understanding churn patterns is essential for strategic decision-making.
#
# This project aims to:
#
# 🎯 Build a machine learning model to predict customer churn.
#
# 📊 Use features like demographics (Gender, SeniorCitizen), service usage (Tenure, Contract, PaymentMethod), and account details (MonthlyCharges, TotalCharges) to analyze customer behavior.
#
# 🤝 Support proactive retention strategies to improve customer loyalty.
#
# 💼 Assist business teams in making data-driven decisions to reduce churn.
# </div>

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 70%; margin: auto;">
# <h3 style="color:#D00000; margin-bottom: 20px;">✅ Tasks:</h3>
#
# 1. <strong>Data Collection</strong><br>
#    - Obtain a telecom customer churn dataset with features such as demographics, service usage, contract type, and billing details.
#
# 2. <strong>Data Preprocessing</strong><br>
#    - Handle missing values<br>
#    - Encode categorical variables (e.g., Gender, Contract)<br>
#    - Convert data types where needed<br>
#    - Scale or normalize numerical features
#
# 3. <strong>Exploratory Data Analysis (EDA)</strong><br>
#    - Understand customer distribution and churn rates<br>
#    - Visualize key feature relationships with churn<br>
#    - Detect class imbalance and patterns in customer behavior
#
# 4. <strong>Feature Engineering</strong><br>
#    - Derive new insights from existing features (e.g., customer lifetime value)<br>
#    - Select top predictive features
#
# 5. <strong>Model Building</strong><br>
#    - Train various classification models (e.g., Logistic Regression, Random Forest, XGBoost)<br>
#    - Evaluate models using accuracy, precision, recall, F1-score, ROC-AUC
#
# 6. <strong>Model Optimization</strong><br>
#    - Perform hyperparameter tuning<br>
#    - Use cross-validation to avoid overfitting
#
# 7. <strong>Deployment</strong><br>
#    - Develop a prediction pipeline<br>
#    - Build a web interface using Streamlit or Flask to make predictions on new customer data
#
# 8. <strong>Documentation & Reporting</strong><br>
#    - Document the code, steps, and findings<br>
#    - Provide visualizations and a summary report for business stakeholders
# </div>

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:center; width: 90%; margin: auto;">
# <h2 style="color:#D00000; margin-bottom: 20px;">Please Upvote my kernel if you like my work.</h2>

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">📚 Import Libraries</p>

# %%
# 📦 Data Handling
import pandas as pd
import numpy as np

# 📊 Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# 🧹 Data Preprocessing
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.preprocessing import LabelEncoder, OneHotEncoder, OrdinalEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler, MaxAbsScaler, QuantileTransformer, PowerTransformer, Normalizer, Binarizer
from sklearn.impute import SimpleImputer, KNNImputer

# 🤖 Machine Learning Models (Classification Problem)
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_auc_score, roc_curve, f1_score, precision_score, recall_score

# 🛠 Warnings
import warnings
warnings.filterwarnings("ignore")

# 🧾 Display Settings
pd.set_option('display.max_columns', None)

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">📖 Read & Explore the Data</p>

# %% [markdown]
# ## 1. Synthetic Dataset Creation for Customer Churn Prediction

# %%
np.random.seed(42)

n = 10000

data = pd.DataFrame({

  'CustomerID': np.arange(n),

  'Gender': np.random.choice(['Male', 'Female'], size=n),

  'SeniorCitizen': np.random.choice([0, 1], size=n),

  'Tenure': np.random.randint(1, 72, size=n),

  'MonthlyCharges': np.round(np.random.uniform(20, 120, size=n), 2),

  'TotalCharges': lambda df: df['Tenure'] * df['MonthlyCharges'],

  'Contract': np.random.choice(['Month-to-month', 'One year', 'Two year'], size=n),

  'PaymentMethod': np.random.choice(['Electronic check', 'Mailed check', 'Bank transfer', 'Credit card'], size=n),

  'Churn': np.random.choice([0, 1], size=n, p=[0.73, 0.27])

})

data['TotalCharges'] = (data['Tenure'] * data['MonthlyCharges']).round(2)

data.to_csv('data/customer_churn_data.csv', index=False)

# %% [markdown]
# ## 2. Read the Dataset

# %%
df = pd.read_csv('data/customer_churn_data.csv')

# %%
df.head()
# Out:
#    CustomerID  Gender  SeniorCitizen  Tenure  MonthlyCharges  TotalCharges  \
# 0           0    Male              0      55          111.88       6153.40
# 1           1  Female              1      36           58.70       2113.20
# 2           2    Male              0      37          118.86       4397.82
# 3           3    Male              1      14           96.14       1345.96
# 4           4    Male              1      27           28.05        757.35
#
#          Contract     PaymentMethod  Churn
# 0        Two year      Mailed check      0
# 1        Two year  Electronic check      0
# 2        One year  Electronic check      0
# 3  Month-to-month      Mailed check      1
# 4        Two year      Mailed check      0

# %% [markdown]
# ## 3. Dataset Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   CustomerID      10000 non-null  int64
#  1   Gender          10000 non-null  object
#  2   SeniorCitizen   10000 non-null  int64
#  3   Tenure          10000 non-null  int64
#  4   MonthlyCharges  10000 non-null  float64
#  5   TotalCharges    10000 non-null  float64
#  6   Contract        10000 non-null  object
#  7   PaymentMethod   10000 non-null  object
#  8   Churn           10000 non-null  int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 703.3+ KB

# %%
df['Churn'] = df['Churn'].astype('object')
df['SeniorCitizen'] = df['SeniorCitizen'].astype('object')

# %%
df.dtypes
# Out:
# CustomerID          int64
# Gender             object
# SeniorCitizen      object
# Tenure              int64
# MonthlyCharges    float64
# TotalCharges      float64
# Contract           object
# PaymentMethod      object
# Churn              object
# dtype: object

# %% [markdown]
# ## 4. Dataset Shape

# %%
df.shape
# Out:
# (10000, 9)

# %% [markdown]
# ## 5. Dataset Columns

# %%
df.columns
# Out:
# Index(['CustomerID', 'Gender', 'SeniorCitizen', 'Tenure', 'MonthlyCharges',
#        'TotalCharges', 'Contract', 'PaymentMethod', 'Churn'],
#       dtype='object')

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 90%; margin: auto;">
# <h2 style="color:#D00000; margin-bottom: 20px;">📌 Observation 1 – Customer Churn Dataset</h2>

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 90%; margin: auto;">
#
# ### 🧾 Dataset Overview
#
# | Description       | Value       |
# |-------------------|-------------|
# | Total Rows        | 10,000      |
# | Total Columns     | 9           |
#
# ### 🗂️ Features & Data Types
#
# - **Demographics:** Gender (object), SeniorCitizen (object)
# - **Account Details:** Tenure (int), MonthlyCharges (float), TotalCharges (float), Contract (object), PaymentMethod (object)
# - **Identifier:** CustomerID (int)
# - **Target Variable:** Churn (object)
#
# ---
#
# This dataset consists of 10,000 customer records capturing demographic information, account details, and churn status, making it suitable for predictive modeling on customer retention.
#
# </div>

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">🔍 Check Missing Values in Dataset</p>

# %% [markdown]
# ## 1. Check Missing Values

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# CustomerID        0
# Gender            0
# SeniorCitizen     0
# Tenure            0
# MonthlyCharges    0
# TotalCharges      0
# Contract          0
# PaymentMethod     0
# Churn             0
# dtype: int64

# %% [markdown]
# ## 2. Visualize Missing Values

# %%
plt.rcParams["figure.figsize"] = (20,6)
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap="viridis")
plt.title("Missing Values")
# Out:
# Text(0.5, 1.0, 'Missing Values')

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 90%; margin: auto;">
# <h2 style="color:#D00000; margin-bottom: 20px;">📌 Observation 2: Missing Values</h2>
#
# - There are **no missing values** in the dataset.
# - All columns are **complete and ready** for analysis and model building.

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">🔁 Check Duplicates in Dataset</p>

# %% [markdown]
# ## 1. Check Duplicates Value

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 90%; margin: auto;">
# <h2 style="color:#D00000; margin-bottom: 20px;">📌 Observation 3: Duplicate Records</h2>
#
# - No duplicate records were found in the dataset.
# - Each entry represents a unique customer, ensuring data integrity and reliability for further analysis.

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">📊 Descriptive Analysis</p>

# %%
df.nunique()
# Out:
# CustomerID        10000
# Gender                2
# SeniorCitizen         2
# Tenure               71
# MonthlyCharges     6302
# TotalCharges       9723
# Contract              3
# PaymentMethod         4
# Churn                 2
# dtype: int64

# %% [markdown]
# ## 1. Numerical Columns Description

# %%
with pd.option_context('float_format', '{:.2f}'.format): 
    display(df.describe())
# Out:
#        CustomerID   Tenure  MonthlyCharges  TotalCharges
# count    10000.00 10000.00        10000.00      10000.00
# mean      4999.50    35.95           70.45       2541.81
# std       2886.90    20.50           28.94       1879.65
# min          0.00     1.00           20.00         21.20
# 25%       2499.75    18.00           45.53       1035.06
# 50%       4999.50    36.00           70.59       2117.14
# 75%       7499.25    54.00           95.61       3717.35
# max       9999.00    71.00          120.00       8384.39

# %%
for col in df.describe().columns:
    print(f"Column Name: ", col)
    print(f"Maximum Value: ", df[col].max())
    print(f"Numbers of Unique Values:", df[col].nunique())
    print("-"*100)
# Out:
# Column Name:  CustomerID
# Maximum Value:  9999
# Numbers of Unique Values: 10000
# ----------------------------------------------------------------------------------------------------
# Column Name:  Tenure
# Maximum Value:  71
# Numbers of Unique Values: 71
# ----------------------------------------------------------------------------------------------------
# Column Name:  MonthlyCharges
# Maximum Value:  120.0
# Numbers of Unique Values: 6302
# ----------------------------------------------------------------------------------------------------
# Column Name:  TotalCharges
# Maximum Value:  8384.39
# Numbers of Unique Values: 9723
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 90%; margin: auto;">
# <h2 style="color:#D00000; margin-bottom: 20px;">📌 Observation 4: 📊 Numerical Feature Analysis</h2>
#
# - **CustomerID** is a unique identifier ranging from 0 to 9999, indicating 10,000 distinct records.
#
# - **Tenure** (in months) has a wide range from 1 to 71, with a median of 36 months, suggesting a balanced mix of new and loyal customers.
#
# - **MonthlyCharges** vary from \$20 to \$120, with a mean of \$70.45. This suggests diverse pricing plans.
#
# - **TotalCharges** reflects the cumulative billing and shows a strong positive correlation with tenure and monthly charges. The wide spread indicates varying levels of customer engagement and plan selection.

# %% [markdown]
# ## 2. Categorical Columns Description

# %%
df.describe(include="object")
# Out:
#        Gender  SeniorCitizen  Contract     PaymentMethod  Churn
# count   10000          10000     10000             10000  10000
# unique      2              2         3                 4      2
# top      Male              0  One year  Electronic check      0
# freq     5013           5007      3455              2516   7330

# %%
for col in df.describe(include="object").columns:
    print(f"Column Name: ", col)
    print(f"Number of frequencies: ", df[col].mode()[0])
    print(f"Numbers of Unique Values:", df[col].nunique())
    print(f"Unique Values:\n", df[col].unique())
    print(f"Unique Values Counts:\n", df[col].value_counts())
    print("-"*100)
# Out:
# Column Name:  Gender
# Number of frequencies:  Male
# Numbers of Unique Values: 2
# Unique Values:
#  ['Male' 'Female']
# Unique Values Counts:
#  Gender
# Male      5013
# Female    4987
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Column Name:  SeniorCitizen
# Number of frequencies:  0
# Numbers of Unique Values: 2
# Unique Values:
#  [0 1]
# Unique Values Counts:
#  SeniorCitizen
# 0    5007
# 1    4993
# Name: count, dtype: int64
# ----------------------------------------------------------------------------------------------------
# Column Name:  Contract
# Number of frequencies:  One year
# Numbers of Unique Values: 3
# Unique Values:
#  ['Two year' 'One year' 'Month-to-month']
# Unique Values Counts:
#  Contract
# One year          3455
# Two year          3326
# Month-to-month    3219
# Name: count, dtype: int64
# ...

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 90%; margin: auto;">
# <h2 style="color:#D00000; margin-bottom: 20px;">📌 Observation 5: 📊 Categorical Feature Analysis</h2>

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 90%; margin: auto;">
#
# Below is a detailed summary of the key categorical columns in the dataset, highlighting the unique values, their frequencies, and notable patterns.
#
# ---
#
# #### 1. 🧑 Gender
# - **Unique Values:** 2 (`Male`, `Female`)
# - **Most Frequent:** `Male` (5,013 customers)
# - **Value Counts:**
#   - Male: 5,013
#   - Female: 4,987
#
# > 🔍 The gender distribution is nearly balanced.
#
# ---
#
# #### 2. 👴 SeniorCitizen
# - **Unique Values:** 2 (`0` = Not Senior, `1` = Senior)
# - **Most Frequent:** `0` (5,007 customers)
# - **Value Counts:**
#   - Not Senior (0): 5,007
#   - Senior (1): 4,993
#
# > 🧓 There is an even mix of senior and non-senior citizens in the dataset.
#
# ---
#
# #### 3. 📄 Contract
# - **Unique Values:** 3 (`Month-to-month`, `One year`, `Two year`)
# - **Most Frequent:** `One year` (3,455 customers)
# - **Value Counts:**
#   - One year: 3,455
#   - Two year: 3,326
#   - Month-to-month: 3,219
#
# > 📝 One-year contracts are slightly more common, but all types are well represented.
#
# ---
#
# #### 4. 💳 Payment Method
# - **Unique Values:** 4 (`Electronic check`, `Mailed check`, `Bank transfer`, `Credit card`)
# - **Most Frequent:** `Electronic check` (2,516 customers)
# - **Value Counts:**
#   - Electronic check: 2,516
#   - Bank transfer: 2,508
#   - Credit card: 2,492
#   - Mailed check: 2,484
#
# > 💰 All payment methods are nearly equally used, with a slight preference for electronic checks.
#
# ---
#
# #### 5. 🔁 Churn
# - **Unique Values:** 2 (`0` = Not Churned, `1` = Churned)
# - **Most Frequent:** `0` (7,330 customers)
# - **Value Counts:**
#   - Not Churned (0): 7,330
#   - Churned (1): 2,670
#
# > ❗ Approximately **27%** of customers have churned, indicating a significant group worth analyzing further.
#
# ---

# %% [markdown]
# # <p style="padding:10px;background-color:#87CEEB ;margin:10;color:#000000;font-family:newtimeroman;font-size:100%;text-align:center;border-radius: 10px 10px ;overflow:hidden;font-weight:50">📈 Data Visualizations</p>

# %%
numerical_columns = list(df.columns[df.dtypes!='object'])
categorical_columns = list(df.columns[df.dtypes=='object'])
print(f'Numerical Columns   : {numerical_columns}')
print(f'Categorical Columns : {categorical_columns}')
# Out:
# Numerical Columns   : ['CustomerID', 'Tenure', 'MonthlyCharges', 'TotalCharges']
# Categorical Columns : ['Gender', 'SeniorCitizen', 'Contract', 'PaymentMethod', 'Churn']

# %% [markdown]
# ## 1. Univariate analysis for categorical variables

# %%
# Set Seaborn style
sns.set(style='whitegrid')
palette = sns.color_palette("Set2")

# Loop through categorical columns
for col in categorical_columns:
    plt.figure(figsize=(8, 5))
    ax = sns.countplot(data=df, x=col, palette=palette)
    
    total = len(df)
    for p in ax.patches:
        count = p.get_height()
        percentage = f'{100 * count / total:.1f}%'
        x = p.get_x() + p.get_width() / 2
        y = p.get_height() / 2  # Mid-bar position
        ax.annotate(percentage, (x, y), ha='center', va='center', fontsize=11, color='black', fontweight='bold')
    
    plt.title(f'Distribution of {col}', fontsize=14, fontweight='bold', color='darkblue')
    plt.xlabel(col, fontsize=12)
    plt.ylabel('Count', fontsize=12)
    plt.xticks(rotation=45)

    # Add legend for categories
    handles, labels = ax.get_legend_handles_labels()
    if not handles:  # If legend not automatically added (e.g., for Gender), add manually
        unique_vals = df[col].unique()
        custom_handles = [plt.Rectangle((0,0),1,1, color=palette[i]) for i in range(len(unique_vals))]
        plt.legend(custom_handles, unique_vals, title=col, bbox_to_anchor=(1.05, 1), loc='upper left')
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 90%; margin: auto;">
# <h2 style="color:#D00000; margin-bottom: 20px;">📌 Observation 6 – Univariate Analysis of Categorical Variables</h2>

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 90%; margin: auto;">
#
# The analysis of key categorical features from the dataset reveals the following balanced and insightful distribution patterns:
#
# - **🧑 Gender:**
#   The gender distribution is nearly equal, with **Male (50.1%)** and **Female (49.9%)**, indicating no gender bias in customer representation.
#
# - **👴 Senior Citizen:**
#   The population is evenly split between **non-senior citizens (50.1%)** and **senior citizens (49.9%)**, allowing for fair analysis across age groups.
#
# - **📄 Contract Type:**
#   All contract types are well-represented:
#   - **One year:** 34.5%
#   - **Two year:** 33.3%
#   - **Month-to-month:** 32.2%
#   This balanced spread indicates a diverse range of customer commitment levels.
#
# - **💳 Payment Method:**
#   All payment methods are almost equally used, reflecting flexibility in customer preferences:
#   - **Electronic Check:** 25.2%
#   - **Bank Transfer:** 25.1%
#   - **Credit Card:** 24.9%
#   - **Mailed Check:** 24.8%
#
# - **🔁 Churn:**
#   The churn rate stands at **26.7%**, with **73.3%** of customers retained. This suggests that nearly **1 out of every 4 customers** tends to leave, which is significant and warrants further investigation into the causes.
#
# > 🎯 These distributions highlight a balanced dataset across key demographics and customer attributes, ensuring unbiased insights in downstream analysis.

# %% [markdown]
# ## 2. Univariate Analysis of Numerical Variables

# %%
numerical_columns  = df[['Tenure', 'MonthlyCharges', 'TotalCharges']]

# %%
# Set style
sns.set(style="whitegrid")
plt.figure(figsize=(15, 12))
plt.suptitle('Univariate Distribution of Numerical Features', fontsize=18, fontweight='bold', color='darkblue')

# Loop through numerical columns and plot histograms
for idx, col in enumerate(numerical_columns, 1):
    plt.subplot(3, 2, idx)  # Adjust number of rows/columns as needed
    sns.histplot(df[col], kde=True, color='skyblue', edgecolor='black')
    
    plt.title(f'Distribution of {col}', fontsize=14, color='darkred')
    plt.xlabel(col, fontsize=12)
    plt.ylabel('Frequency', fontsize=12)

plt.tight_layout(rect=[0, 0, 1, 0.96])  # Leave space for the super title
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 90%; margin: auto;">
# <h2 style="color:#D00000; margin-bottom: 20px;">📌 Observation 7 – Univariate Analysis of Numerical Variables</h2>
#
# - **Tenure**: Fairly uniform distribution. Customers are spread across all tenure levels, indicating consistent retention.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# - **Monthly Charges**: Monthly charges are fairly uniformly distributed from $20 to $120. There's no clear skew, indicating balanced usage across low, medium, and high charge plans.
#
# - **Total Charges**: Right-skewed. Majority of customers have low total charges, indicating many are newer or low-usage users.

# %% [markdown]
# ## 3. Bivariate Analysis

# %%
# Set style and color map
plt.figure(figsize=(8, 6))
sns.set(style="whitegrid")

# Create heatmap
sns.heatmap(
    numerical_columns.corr(numeric_only=True),
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5,
    linecolor='gray',
    cbar_kws={"shrink": 0.8},
    square=True
)

# Add title
plt.title("Correlation Heatmap of Numerical Features", fontsize=14, fontweight='bold', color='darkblue')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
# Set style and palette
sns.set(style="whitegrid")
palette = sns.color_palette("Set2")

# Categorical columns except 'Churn'
categorical_columns = df.select_dtypes(include='object').columns.drop('Churn')

# Number of plots
n = len(categorical_columns)
cols = 2  # 2 plots per row
rows = (n + 1) // cols  # Calculate number of rows needed

plt.figure(figsize=(14, 6 * rows))

for i, col in enumerate(categorical_columns, 1):
    plt.subplot(rows, cols, i)
    ax = sns.countplot(data=df, x=col, hue="Churn", palette=palette)

    # Annotate counts on bars
    for p in ax.patches:
        count = int(p.get_height())
        if count > 0:
            x = p.get_x() + p.get_width() / 2
            y = p.get_height() * 0.5 + 5
            ax.annotate(f'{count}', (x, y), ha='center', va='center', fontsize=10, fontweight='bold', color='black')

    plt.title(f"Churn Distribution by {col}", fontsize=13, fontweight='bold', color='darkblue')
    plt.xlabel(col, fontsize=11)
    plt.ylabel("Count", fontsize=11)
    plt.xticks(rotation=45)
    plt.legend(title="Churn", loc='upper right')

plt.tight_layout()
plt.show()

# %%
# Set style
sns.set(style="whitegrid")
palette = sns.color_palette("Set2")

# List of numerical features
numerical_features = ['Tenure', 'MonthlyCharges', 'TotalCharges']

# Create subplots: 1 row, 3 columns
plt.figure(figsize=(18, 5))

for i, feature in enumerate(numerical_features, 1):
    plt.subplot(1, 3, i)
    sns.boxplot(data=df, x='Churn', y=feature, palette=palette)
    plt.title(f'{feature} vs Churn', fontsize=13, fontweight='bold', color='darkblue')
    plt.xlabel("Churn")
    plt.ylabel(feature)

plt.tight_layout()
plt.show()

# %%
sns.set(style="whitegrid")
palette = sns.color_palette("Set2")  

numerical_features = ['Tenure', 'MonthlyCharges', 'TotalCharges']

plt.figure(figsize=(18, 5))

for i, feature in enumerate(numerical_features, 1):
    plt.subplot(1, 3, i)
    ax = sns.kdeplot(df[feature][df["Churn"] == 0], color=palette[0], shade=True)
    ax = sns.kdeplot(df[feature][df["Churn"] == 1], color=palette[1], shade=True)
    ax.legend(["Not Churn", "Churn"], loc='upper right')
    ax.set_xlabel(feature)
    ax.set_ylabel('Density')
    ax.set_title(f'Distribution of {feature} by Churn')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 90%; margin: auto;">
# <h2 style="color:#D00000; margin-bottom: 20px;">📌 Observation 8 – Customer Churn Analysis Report</h2>

# %% [markdown]
# <div style="border-radius:10px; border:#000000 solid; padding: 20px; background-color: black; font-size:16px; color: #ffffff; text-align:left; width: 90%; margin: auto;">
#
# ### 🔷 1. Correlation Heatmap of Numerical Features
#
# #### 🔍 Insights:
# - **Tenure and TotalCharges** have a **strong positive correlation** (`0.77`). Customers with longer tenure tend to have higher total charges.
#
# - **MonthlyCharges and TotalCharges** also show a **moderate correlation** (`0.56`), as expected.
#
# - **Tenure and MonthlyCharges** are **not correlated** (`0.01`), indicating monthly charges are independent of how long the customer has been with the company.
#
# ---
#
# ### 🔷 2. Churn Distribution Across Categorical Features
#
# #### 🔹 Gender vs Churn
#
# | Gender | No Churn | Churn |
# |--------|----------|-------|
# | Male   | 3673     | 1340  |
# | Female | 3657     | 1330  |
#
# - 🔍 **Insight:** Gender does **not** significantly influence churn.
#
# ---
#
# #### 🔹 SeniorCitizen vs Churn
#
# | SeniorCitizen | No Churn | Churn |
# |---------------|----------|-------|
# | No (0)        | 3680     | 1327  |
# | Yes (1)       | 3650     | 1343  |
#
# - 🔍 **Insight:** Slightly higher churn among **senior citizens**, but the difference is **marginal**.
#
# ---
#
# #### 🔹 Contract Type vs Churn
#
# | Contract Type     | No Churn | Churn |
# |-------------------|----------|-------|
# | Two year          | 2440     | 886   |
# | One year          | 2517     | 938   |
# | Month-to-month    | 2373     | **846**   |
#
# - 🔍 **Insight:** Contrary to common assumptions, **Month-to-month customers show the lowest churn** in this dataset.
#
# ---
#
# #### 🔹 Payment Method vs Churn
#
# | Payment Method        | No Churn | Churn |
# |------------------------|----------|-------|
# | Mailed check           | 1832     | 652   |
# | Electronic check       | 1845     | 671   |
# | Bank transfer (auto)   | 1836     | 672   |
# | Credit card (auto)     | 1817     | 675   |
#
# - 🔍 **Insight:** **Payment method** has **no significant effect** on churn rates.
#
# ---
#
# ### ✅ Summary
#
# - Tenure and total charges are positively correlated, while monthly charges are unrelated to tenure.
#
# - Gender and payment method have **no impact** on churn.
#
# - **Slight churn increase** among senior citizens.
#
# - Most surprisingly, **Month-to-month contracts** show the **lowest churn**, which might indicate recent customer acquisition or effective retention efforts.
